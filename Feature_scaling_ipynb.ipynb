# %% [markdown]
# <a href="https://colab.research.google.com/github/itsahmadabdullah/100-days-ML-learning/blob/main/Feature_scaling_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with high variation
data = {
    'age': [22, 25, 47, 52, 46, 56, 48, 55],               # low-medium variation
    'income': [25000, 32000, 60000, 58000, 62000, 120000, 115000, 150000],  # high variation
    'experience': [1, 3, 20, 23, 19, 30, 22, 28]            # medium variation
}

df = pd.DataFrame(data)

df
# Out:
#    age  income  experience
# 0   22   25000           1
# 1   25   32000           3
# 2   47   60000          20
# 3   52   58000          23
# 4   46   62000          19
# 5   56  120000          30
# 6   48  115000          22
# 7   55  150000          28

# %%
# lets check the distribution fo all colimns
for col in df.columns:
    print(f"Distribution of {col}:")
    sns.histplot(df[col], kde=True)
    plt.show()
# Out:
# Distribution of age:
# Distribution of income:
# Distribution of experience:

# %%
# performmt the normalization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
df_scaled
# Out:
#         age    income  experience
# 0 -1.783951 -1.251108   -1.721239
# 1 -1.539294 -1.085084   -1.521675
# 2  0.254850 -0.420989    0.174618
# 3  0.662610 -0.468424    0.473964
# 4  0.173298 -0.373554    0.074836
# 5  0.988818  1.002072    1.172438
# 6  0.336402  0.883484    0.374182
# 7  0.907266  1.713603    0.972874

# %%
# plot the scaled data
for col in df_scaled.columns:
    print(f"Distribution of {col}:")
    sns.histplot(df_scaled[col], kde=True)
    plt.show()
# Out:
# Distribution of age:
# Distribution of income:
# Distribution of experience:

# %% [markdown]
# # Min Max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(10,12))  # custom range
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
df_scaled
# Out:
#          age  income  experience
# 0  10.000000  10.000   10.000000
# 1  10.176471  10.112   10.137931
# 2  11.470588  10.560   11.310345
# 3  11.764706  10.528   11.517241
# 4  11.411765  10.592   11.241379
# 5  12.000000  11.520   12.000000
# 6  11.529412  11.440   11.448276
# 7  11.941176  12.000   11.862069
